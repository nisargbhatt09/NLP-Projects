# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 3.7 MB/s
# Requirement already satisfied: requests>=2.19.0 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.23 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from pandas_datareader) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (2020.5)
# Requirement already satisfied: numpy>=1.15.4 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/nisarg/anaconda3/envs/ml/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Collecting lxml
#   Downloading lxml-4.6.3-cp36-cp36m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 11.0 MB/s
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.6.3 pandas-datareader-0.10.0

# %%
import pandas_datareader as pdr

# %%
df = pdr.get_data_tiingo('AAPL', api_key = "4498328d77d2ee1d6e02e16fb9d5f2aeace6af2e")

# %%
import pandas as pd

# %%
df.to_csv('AAPL.csv')

# %%
df2 = df.reset_index()['close']

# %%
df
# Out:
#                                    close      high     low    open    volume  \
# symbol date
# AAPL   2016-08-16 00:00:00+00:00  109.38  110.2300  109.21  109.63  33794448
#        2016-08-17 00:00:00+00:00  109.22  109.3700  108.34  109.10  25355976
#        2016-08-18 00:00:00+00:00  109.08  109.6000  109.02  109.23  21984703
#        2016-08-19 00:00:00+00:00  109.36  109.6900  108.36  108.77  25368072
#        2016-08-22 00:00:00+00:00  108.51  109.1000  107.85  108.86  25820230
# ...                                  ...       ...     ...     ...       ...
#        2021-08-09 00:00:00+00:00  146.09  146.7000  145.52  146.20  48908689
#        2021-08-10 00:00:00+00:00  145.60  147.7100  145.30  146.44  69023081
#        2021-08-11 00:00:00+00:00  145.86  146.7200  145.53  146.05  48493463
#        2021-08-12 00:00:00+00:00  148.89  149.0500  145.84  146.19  73779113
#        2021-08-13 00:00:00+00:00  149.10  149.4444  148.27  148.97  58846293
#
#                                     adjClose     adjHigh      adjLow  \
# symbol date
# AAPL   2016-08-16 00:00:00+00:00   25.640617   25.839872   25.600766
#        2016-08-17 00:00:00+00:00   25.603110   25.638273   25.396822
#        2016-08-18 00:00:00+00:00   25.570292   25.692189   25.556227
#        2016-08-19 00:00:00+00:00   25.635929   25.713286   25.401511
#        2016-08-22 00:00:00+00:00   25.436673   25.574980   25.281958
# ...                                      ...         ...         ...
#        2021-08-09 00:00:00+00:00  146.090000  146.700000  145.520000
#        2021-08-10 00:00:00+00:00  145.600000  147.710000  145.300000
#        2021-08-11 00:00:00+00:00  145.860000  146.720000  145.530000
#        2021-08-12 00:00:00+00:00  148.890000  149.050000  145.840000
#        2021-08-13 00:00:00+00:00  149.100000  149.444400  148.270000
#
#                                      adjOpen  adjVolume  divCash  splitFactor
# symbol date
# AAPL   2016-08-16 00:00:00+00:00   25.699221  135177792      0.0          1.0
#        2016-08-17 00:00:00+00:00   25.574980  101423904      0.0          1.0
#        2016-08-18 00:00:00+00:00   25.605454   87938812      0.0          1.0
#        2016-08-19 00:00:00+00:00   25.497622  101472288      0.0          1.0
#        2016-08-22 00:00:00+00:00   25.518720  103280920      0.0          1.0
# ...                                      ...        ...      ...          ...
#        2021-08-09 00:00:00+00:00  146.200000   48908689      0.0          1.0
#        2021-08-10 00:00:00+00:00  146.440000   69023081      0.0          1.0
#        2021-08-11 00:00:00+00:00  146.050000   48493463      0.0          1.0
#        2021-08-12 00:00:00+00:00  146.190000   73779113      0.0          1.0
#        2021-08-13 00:00:00+00:00  148.970000   58846293      0.0          1.0
#
# [1258 rows x 12 columns]

# %%
df2
# Out:
# 0       109.38
# 1       109.22
# 2       109.08
# 3       109.36
# 4       108.51
#          ...
# 1253    146.09
# 1254    145.60
# 1255    145.86
# 1256    148.89
# 1257    149.10
# Name: close, Length: 1258, dtype: float64

# %%
df2.shape
# Out:
# (1258,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df2)

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df2).reshape(-1, 1))

# %%
df1
# Out:
# array([[0.01551022],
#        [0.01511316],
#        [0.01476573],
#        ...,
#        [0.1060403 ],
#        [0.11355966],
#        [0.1140808 ]])

# %%
training_size = int(len(df1) * 0.65)
